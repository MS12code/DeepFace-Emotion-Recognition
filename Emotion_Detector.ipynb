# %% [markdown]
# <a href="https://colab.research.google.com/github/MS12code/DeepFace-Emotion-Recognition/blob/main/Emotion_Detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 78.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.5 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=dd4b2df5bd7b462b330e7bdef7092fe9dab7627f934e4a08a39809e13ae4047d
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')

img_path = "/content/drive/MyDrive/Colab Notebooks/DeepLearning_proj/happyboy.jpg"
img = cv2.imread(img_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Display image using matplotlib (convert BGR to RGB for correct colors)
import matplotlib.pyplot as plt # Import pyplot module instead of just matplotlib
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# Analyze emotions using DeepFace
# Make sure to import DeepFace if it hasn't been already
from deepface import DeepFace
predictions = DeepFace.analyze(img, actions=['emotion'])
print(predictions)
# Out:
# 25-05-27 07:11:47 - Directory /root/.deepface has been created
# 25-05-27 07:11:47 - Directory /root/.deepface/weights has been created
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 25-05-27 07:11:49 - facial_expression_model_weights.h5 will be downloaded...
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 251MB/s]
# [{'emotion': {'angry': np.float32(3.0663139e-09), 'disgust': np.float32(3.8654505e-12), 'fear': np.float32(1.0554136e-05), 'happy': np.float32(99.99621), 'sad': np.float32(4.3936117e-07), 'surprise': np.float32(2.1332946e-06), 'neutral': np.float32(0.003779466)}, 'dominant_emotion': 'happy', 'region': {'x': 259, 'y': 227, 'w': 457, 'h': 457, 'left_eye': (568, 418), 'right_eye': (403, 393)}, 'face_confidence': np.float64(0.95)}]

# %%
predictions = DeepFace.analyze(img)
print(predictions)
# Out:
# Action: age:   0%|          | 0/4 [00:00<?, ?it/s]    Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# 25-05-27 07:11:54 - age_model_weights.h5 will be downloaded...
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   4%|▎         | 19.4M/539M [00:00<00:02, 193MB/s]
#   8%|▊         | 41.9M/539M [00:00<00:02, 212MB/s]
#  12%|█▏        | 63.4M/539M [00:00<00:02, 179MB/s]
#  15%|█▌        | 82.3M/539M [00:00<00:02, 160MB/s]
#  19%|█▉        | 105M/539M [00:00<00:02, 179MB/s]
#  23%|██▎       | 124M/539M [00:00<00:03, 133MB/s]
#  26%|██▌       | 139M/539M [00:00<00:03, 129MB/s]
#  28%|██▊       | 153M/539M [00:01<00:03, 128MB/s]
#  31%|███▏      | 169M/539M [00:01<00:02, 132MB/s]
#  34%|███▍      | 183M/539M [00:01<00:03, 112MB/s]
#  37%|███▋      | 200M/539M [00:01<00:02, 125MB/s]
#  40%|███▉      | 215M/539M [00:01<00:02, 131MB/s]
# ...

# %%
type(predictions)
# Out:
# list

# %%
# Access the first (and only) dictionary in the list
analysis_result = predictions[0]

# Access the 'dominant_emotion' key from the dictionary
dominant_emotion = analysis_result['dominant_emotion']

print(f"The dominant emotion is: {dominant_emotion}")
# Out:
# The dominant emotion is: happy

# %% [markdown]
# Trying to make the rectagular box here

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray, 1.1, 4)

font = cv2.FONT_HERSHEY_SIMPLEX

for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Predict emotion on the face region (you likely already have this as dominant_emotion)
    # For demo, using a static value:
    dominant_emotion = "happy"  # Replace with actual emotion from DeepFace

    # Draw the emotion label just above the rectangle
    cv2.putText(img,
                dominant_emotion,
                (x, y - 10),
                font, 1,
                (0, 0, 255),
                2,
                cv2.LINE_4)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# Install required libraries if not already installed
# !pip install deepface --quiet
# !pip install opencv-python-headless --quiet

# Import necessary libraries
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# Load the image using OpenCV (BGR format)
img_bgr = cv2.imread("/content/drive/MyDrive/Colab Notebooks/DeepLearning_proj/sad_women.jpg")

# Convert BGR to RGB for DeepFace
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# Show the image using matplotlib
plt.imshow(img_rgb)
plt.axis('off')  # Hide axis
plt.show()

# Run DeepFace analysis, allowing for no face detection
# Set enforce_detection to False so it doesn't throw an error if no face is found
results = DeepFace.analyze(img_rgb, actions=['emotion'], enforce_detection=False)

# Check if any faces were detected before accessing the results
if results:
    # Print the full emotion scores
    print("All emotion probabilities:")
    print(results[0]['emotion'])

    # Print only the dominant emotion
    print("Dominant emotion:", results[0]['dominant_emotion'])
else:
    print("No face detected in the image.")
# Out:
# All emotion probabilities:
# {'angry': np.float32(0.16596676), 'disgust': np.float32(2.7987384e-05), 'fear': np.float32(0.8244407), 'happy': np.float32(0.00074477354), 'sad': np.float32(32.625477), 'surprise': np.float32(0.00036925473), 'neutral': np.float32(66.38297)}
# Dominant emotion: neutral

# %%
# Access the first (and only) dictionary in the list
analysis_result = predictions[0]

# Access the 'dominant_emotion' key from the dictionary
dominant_emotion = analysis_result['dominant_emotion']

print(f"The dominant emotion is: {dominant_emotion}")
# Out:
# The dominant emotion is: neutral

# %%
img2 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/DeepLearning_proj/angry_women.jpg')

# %%
plt.imshow(img2)

# %%
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# Show the image using matplotlib
plt.imshow(img2_rgb)
plt.axis('off')  # Optional: turn off axis
plt.show()

# %%
# Analyze the image with enforce_detection set to False
predictions = DeepFace.analyze(img2_rgb, enforce_detection=False)

# Print the results - it might be an empty list if no face was found
print(predictions)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.95it/s]
# [{'emotion': {'angry': np.float32(47.13667), 'disgust': np.float32(0.0068318797), 'fear': np.float32(3.95137), 'happy': np.float32(0.8733241), 'sad': np.float32(18.195482), 'surprise': np.float32(0.23781255), 'neutral': np.float32(29.598507)}, 'dominant_emotion': 'angry', 'region': {'x': 432, 'y': 92, 'w': 166, 'h': 166, 'left_eye': (549, 158), 'right_eye': (480, 154)}, 'face_confidence': np.float64(0.92), 'age': 32, 'gender': {'Woman': np.float32(99.43744), 'Man': np.float32(0.5625619)}, 'dominant_gender': 'Woman', 'race': {'asian': np.float32(0.23945314), 'indian': np.float32(0.15909247), 'black': np.float32(0.042866245), 'white': np.float32(73.69422), 'middle eastern': np.float32(5.34978), 'latino hispanic': np.float32(20.514585)}, 'dominant_race': 'white'}]

# %%
# Access the first (and only) dictionary in the list
analysis_result = predictions[0]

# Access the 'dominant_emotion' key from the dictionary
dominant_emotion = analysis_result['dominant_emotion']

print(f"The dominant emotion is: {dominant_emotion}")
# Out:
# The dominant emotion is: angry

# %% [markdown]
# Real Time Video Demo for Face Emotion Recognition.

# %%
# Install necessary libraries
# !pip install deepface --quiet
# !pip install opencv-python-headless --quiet

# Import required libraries
import cv2
import numpy as np
import base64
from deepface import DeepFace
from google.colab.output import eval_js
from IPython.display import display, Javascript
from google.colab.patches import cv2_imshow
import time

# JavaScript to access webcam
def start_webcam():
    display(Javascript('''
        async function startWebcam() {
            const div = document.createElement('div');
            const video = document.createElement('video');
            video.setAttribute("playsinline", true);
            video.style.display = 'none';
            div.appendChild(video);
            document.body.appendChild(div);

            const stream = await navigator.mediaDevices.getUserMedia({video: true});
            video.srcObject = stream;
            await video.play();

            window.captureFrame = () => {
                const canvas = document.createElement('canvas');
                canvas.width = video.videoWidth;
                canvas.height = video.videoHeight;
                canvas.getContext('2d').drawImage(video, 0, 0);
                return canvas.toDataURL('image/jpeg', 0.9);
            };
        }
        startWebcam();
    '''))

# Capture a single frame from webcam
def capture_frame():
    data = eval_js('captureFrame()')
    if data is None:
        return None
    data = data.split(',')[1]
    img_bytes = base64.b64decode(data)
    img_array = np.frombuffer(img_bytes, dtype=np.uint8)
    img = cv2.imdecode(img_array, cv2.IMREAD_COLOR)
    return img

# Start webcam and wait for it to initialize
start_webcam()
time.sleep(3)

# Load face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

print("🔵 Webcam started. Showing one frame every second. Stop the cell manually to quit.")

try:
    while True:
        frame = capture_frame()
        if frame is None:
            print("No frame captured.")
            continue

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        for (x, y, w, h) in faces:
            face_img = frame[y:y+h, x:x+w]

            try:
                # Analyze emotion using strict detection and debug probabilities
                result = DeepFace.analyze(face_img, actions=['emotion'], enforce_detection=True, detector_backend='opencv')

                emotion_scores = result[0]['emotion']  # All emotion probabilities
                dominant_emotion = result[0]['dominant_emotion']

                print("Emotion Probabilities:", emotion_scores)  # Debug info

            except Exception as e:
                dominant_emotion = "Error"
                print(f"Emotion analysis failed: {e}")

            # Draw results
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
            cv2.putText(frame, dominant_emotion, (x, y - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2, cv2.LINE_AA)

        # Show the frame
        cv2_imshow(frame)
        time.sleep(1.2)  # Adjust this delay

except KeyboardInterrupt:
    print("🟥 Stopped by user.")
# Out:
# 🔵 Webcam started. Showing one frame every second. Stop the cell manually to quit.
# Emotion Probabilities: {'angry': np.float32(2.7902803), 'disgust': np.float32(0.0008027255), 'fear': np.float32(12.124865), 'happy': np.float32(0.04376251), 'sad': np.float32(13.277245), 'surprise': np.float32(0.0009540195), 'neutral': np.float32(71.76209)}
# <PIL.Image.Image image mode=RGB size=640x480>
# Emotion Probabilities: {'angry': np.float32(2.4968128), 'disgust': np.float32(0.01492925), 'fear': np.float32(36.508137), 'happy': np.float32(0.214507), 'sad': np.float32(19.279581), 'surprise': np.float32(0.009756043), 'neutral': np.float32(41.476276)}
# <PIL.Image.Image image mode=RGB size=640x480>
# Emotion Probabilities: {'angry': np.float32(5.0237374), 'disgust': np.float32(0.008805487), 'fear': np.float32(14.260804), 'happy': np.float32(0.19148792), 'sad': np.float32(22.491014), 'surprise': np.float32(0.026544511), 'neutral': np.float32(57.9976)}
# ...
